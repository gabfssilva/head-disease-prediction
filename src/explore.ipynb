# %% [markdown]
# Shape do dataset original:

# %%
import pandas as pd

raw = pd.read_parquet('../resources/processed/raw_dataset.parquet')
raw.shape
# Out:
# (445132, 322)

# %% [markdown]
# Informação sobre a coluna target:

# %%
raw['CVDINFR4'].value_counts()
# Out:
# CVDINFR4
# 2.0    416959
# 1.0     25108
# 7.0      2731
# 9.0       330
# Name: count, dtype: int64

# %% [markdown]
# Shape do dataset de treinamento

# %%
pd.read_parquet('../resources/processed/train.parquet').shape
# Out:
# (353653, 41)

# %% [markdown]
# Shape do dataset de teste

# %%
pd.read_parquet('../resources/processed/test.parquet').shape
# Out:
# (88414, 41)

# %% [markdown]
# Shape do dataset de análise

# %%
df = pd.read_parquet('../resources/processed/analysis.parquet')
df.shape
# Out:
# (35366, 41)

# %% [markdown]
# Inputando informações dos valores nas colunas para facilitar a análise

# %%
headers = pd.read_json('../resources/processed/selected_headers.json')

categorical_cols = df.select_dtypes(include=['object', 'category']).columns

for col, mapping in headers.items():
    if col in categorical_cols:
        df[col] = df[col].map(lambda x: mapping['possible_answers'].get(str(x), str(x)))

df['target'] = df['target'].map({ 'True': 'Yes', 'False': 'No' })

df
# Out:
#              LSATISFY  MAXDRNKS CDHELP  LCSFIRST  LCSLAST  \
# 0           Satisfied       3.0   <NA>      18.0      NaN
# 1           Satisfied       NaN   <NA>       NaN      NaN
# 2                <NA>       NaN   <NA>       NaN      NaN
# 3                <NA>       NaN   <NA>      18.0     28.0
# 4           Satisfied       1.0   <NA>      17.0      NaN
# ...               ...       ...    ...       ...      ...
# 35361            <NA>       2.0   <NA>      17.0     59.0
# 35362            <NA>       NaN   <NA>       NaN      NaN
# 35363  Very satisfied       2.0   <NA>       NaN      NaN
# 35364  Very satisfied       NaN   <NA>       NaN      NaN
# 35365       Satisfied       1.0   <NA>       NaN      NaN
#
#                   _IMPRACE       _RFHLTH  \
# 0      White, Non-Hispanic          Good
# 1                 Hispanic  Fair or Poor
# 2      White, Non-Hispanic          Good
# 3      White, Non-Hispanic          Good
# 4      White, Non-Hispanic          Good
# ...                    ...           ...
# 35361  White, Non-Hispanic          Good
# 35362  White, Non-Hispanic  Fair or Poor
# 35363  White, Non-Hispanic          Good
# 35364  Asian, Non-Hispanic          Good
# 35365  White, Non-Hispanic          Good
#
#                                       _PHYS14D  \
# 0      Zero days when physical health not good
# 1       14+ days when physical health not good
# 2      Zero days when physical health not good
# 3               Don't know / Refused / Missing
# 4      1-13 days when physical health not good
# ...                                        ...
# 35361  Zero days when physical health not good
# 35362  Zero days when physical health not good
# 35363   14+ days when physical health not good
# 35364  Zero days when physical health not good
# 35365  Zero days when physical health not good
#
#                                     _MENT14D  \
# 0      1-13 days when mental health not good
# 1      1-13 days when mental health not good
# 2      Zero days when mental health not good
# 3      Zero days when mental health not good
# 4       14+ days when mental health not good
# ...                                      ...
# 35361  1-13 days when mental health not good
# 35362  Zero days when mental health not good
# 35363   14+ days when mental health not good
# 35364  Zero days when mental health not good
# 35365  Zero days when mental health not good
#
#                                                 _HLTHPLN  ... DIABETE4 DECIDE  \
# 0                            Have some form of insurance  ...       No     No
# 1                            Have some form of insurance  ...       No    Yes
# 2                            Have some form of insurance  ...       No     No
# 3                            Have some form of insurance  ...       No     No
# 4                            Have some form of insurance  ...       No     No
# ...                                                  ...  ...      ...    ...
# 35361                        Have some form of insurance  ...       No     No
# 35362  Don't know, refused or missing insurance response  ...       No     No
# 35363                        Have some form of insurance  ...       No     No
# 35364          Do not have some form of health insurance  ...       No     No
# 35365                        Have some form of insurance  ...       No     No
#
#       DIFFWALK             DIFFDRES DIFFALON CNCRAGE CNCRTYP2  CHCOCNC1  \
# 0           No                   No       No     NaN      NaN        No
# 1          Yes  Don't know/Not Sure      Yes     NaN      NaN        No
# 2           No                   No       No     NaN      NaN        No
# 3           No                   No       No     NaN      NaN        No
# 4           No                   No       No     NaN      NaN        No
# ...        ...                  ...      ...     ...      ...       ...
# 35361       No                   No       No     NaN      NaN        No
# 35362       No                   No       No     NaN      NaN        No
# 35363       No                   No       No     NaN      NaN        No
# 35364       No                   No       No     NaN      NaN        No
# 35365       No                   No       No     NaN      NaN        No
#
#       CVDCRHD4  target
# 0           No      No
# 1           No      No
# 2           No      No
# 3           No      No
# 4           No      No
# ...        ...     ...
# 35361       No      No
# 35362       No      No
# 35363       No      No
# 35364       No      No
# 35365       No      No
#
# [35366 rows x 41 columns]

# %%
df['_BMI5CAT']
# Out:
# 0        Normal Weight
# 1        Normal Weight
# 2          Underweight
# 3                Obese
# 4           Overweight
#              ...
# 35361            Obese
# 35362            Obese
# 35363    Normal Weight
# 35364            Obese
# 35365             <NA>
# Name: _BMI5CAT, Length: 35366, dtype: object

# %%
import plotly.express as px

from util.plots import *

columns = [
    ('_AGE_G', 'asc', 'v'), 
    ('_BMI5CAT', [
        'Underweight', 'Normal Weight', 'Overweight', 'Obese'
    ], 'v'),
    ('_RFHLTH', 'desc', 'v'),
    ('DIABETE4', 'desc', 'v'),
    ('CVDCRHD4', 'desc', 'v'),
    ('CHCKDNY2', 'desc', 'v')
]

# smokgrp = df['_SMOKGRP'].value_counts()
# smokgrp = smokgrp.drop(labels='<NA>').sort_values()

smokgrp = df[df['_SMOKGRP'] != '<NA>']
smokgrp = smokgrp.groupby(['target', '_SMOKGRP']).size().reset_index(name='count')
total_count = smokgrp['count'].sum()
smokgrp['percentage'] = (smokgrp['count'] / total_count) * 100

fig = px.bar(
    smokgrp.sort_values(by=['target', 'percentage']),  
    y='_SMOKGRP', 
    x='percentage',
    color='target',
    orientation='h',
    color_discrete_sequence=[strongcyan, gold],
    labels={
        # '_SMOKGRP': f"_SMOKGRP",
        "target": "Have you ever had a heart attack?",
        'percentage': f'Percentage by _SMOKGRP - Total: {total_count}'
    },
)

fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)

fig.update_traces(
    # hoverinfo='label+percent', 
    text=smokgrp.values,
    # textfont_size=16,
    textposition='inside',
    marker=dict(
        # color=list(colors), 
        line=dict(color='#000000', width=2)
    ),
)

fig.update_layout(
    legend=dict(
        orientation="h",
        yanchor="middle",
        y=-0.3,
        xanchor="center",
        x=0.2
    )
)

fig.show()
fig.write_image(
    f'../resources/generated/bar__SMOKGRP.png', 
    format='png', 
    width=900,
    height=450,
    scale=4
)

for column, sort, orientation in columns:
    barplot(df, column, sort, orientation)

# %%
boxplot(df, x='_AGE80', y='_BMI5CAT', caption='Age Distribution by BMI Category and Heart Attack History')

# %%
from pandas import Series
import plotly.graph_objects as go

colors = ['mediumturquoise', 'gold', '#12AACC', 'orange', '#007EB0']

df_bmi: Series = df['_BMI5CAT'].value_counts()
df_bmi = df_bmi.drop(labels='<NA>')

fig = go.Figure(data=[
    go.Pie(
        labels=df_bmi.keys(), 
        values=df_bmi.values
    )
])

fig.update_layout(
    legend=dict(
        orientation="h",
        yanchor="middle",
        y=-0.3,
        xanchor="center",
        x=0.5
    )
)

fig.update_traces(
    hoverinfo='label+percent', 
    textinfo='percent',
    textfont_size=20,
    textposition='outside',
    marker=dict(
        colors=colors, 
        line=dict(color='#000000', width=2)
    ),
)

fig.show()
